# %%
import pandas as pd

# %%
arima_predictions = pd.read_csv('test_data.csv')

# %%
arima_predictions
# Out:
#           Data  ES080E  ES1000E  ES100E  ES1200E  ES125E  ES150E  ES200E  \
# 0   2021-07-12       8        0      52        0       0      48       8
# 1   2021-07-19      66        0     192        0       0      66     110
# 2   2021-07-26     222        0      66        0       6     260      98
# 3   2021-08-02       0        0       6        0       0      96       0
# 4   2021-08-09      20        0      18        0       0      28       0
# ..         ...     ...      ...     ...      ...     ...     ...     ...
# 77  2023-01-02       0        0       0        0       0      10       4
# 78  2023-01-09      18        0      44        0       4      28      30
# 79  2023-01-16      36        0      24        0       0       4      16
# 80  2023-01-23      14        0      28        0       8      14      34
# 81  2023-01-30      16        0      28        0       0      54      56
#
#     ES200E/16  ES250E  ...  XS500E/16  XS600E  XS600E/16  XS700E  XS700E/16  \
# ...

# %%
arima_predictions.set_index('Data', inplace = True)

# %%
arima_predictions.drop(['Cena rudy żelaza', 'Stan epidemii w Polsce', 'Inflacja'], axis = 'columns', inplace = True)

# %%
arima_predictions
# Out:
#             ES080E  ES1000E  ES100E  ES1200E  ES125E  ES150E  ES200E  \
# Data
# 2021-07-12       8        0      52        0       0      48       8
# 2021-07-19      66        0     192        0       0      66     110
# 2021-07-26     222        0      66        0       6     260      98
# 2021-08-02       0        0       6        0       0      96       0
# 2021-08-09      20        0      18        0       0      28       0
# ...            ...      ...     ...      ...     ...     ...     ...
# 2023-01-02       0        0       0        0       0      10       4
# 2023-01-09      18        0      44        0       4      28      30
# 2023-01-16      36        0      24        0       0       4      16
# 2023-01-23      14        0      28        0       8      14      34
# 2023-01-30      16        0      28        0       0      54      56
#
#             ES200E/16  ES250E  ES250E/16  ...  XS450E  XS450E/16  XS500E  \
# Data                                      ...
# ...

# %%
products = arima_predictions.columns[0:1262]

# %%
products
# Out:
# Index(['ES080E', 'ES1000E', 'ES100E', 'ES1200E', 'ES125E', 'ES150E', 'ES200E',
#        'ES200E/16', 'ES250E', 'ES250E/16',
#        ...
#        'XS450E', 'XS450E/16', 'XS500E', 'XS500E/16', 'XS600E', 'XS600E/16',
#        'XS700E', 'XS700E/16', 'XS800E', 'XS900E'],
#       dtype='object', length=1262)

# %%
arima_predictions[products] = arima_predictions[products].apply(lambda x: x*0)

# %%
arima_predictions
# Out:
#             ES080E  ES1000E  ES100E  ES1200E  ES125E  ES150E  ES200E  \
# Data
# 2021-07-12       0        0       0        0       0       0       0
# 2021-07-19       0        0       0        0       0       0       0
# 2021-07-26       0        0       0        0       0       0       0
# 2021-08-02       0        0       0        0       0       0       0
# 2021-08-09       0        0       0        0       0       0       0
# ...            ...      ...     ...      ...     ...     ...     ...
# 2023-01-02       0        0       0        0       0       0       0
# 2023-01-09       0        0       0        0       0       0       0
# 2023-01-16       0        0       0        0       0       0       0
# 2023-01-23       0        0       0        0       0       0       0
# 2023-01-30       0        0       0        0       0       0       0
#
#             ES200E/16  ES250E  ES250E/16  ...  XS450E  XS450E/16  XS500E  \
# Data                                      ...
# ...

# %%
arima_predictions.to_csv('arima_results.csv')
arima_predictions.to_csv('nbeats_results.csv')
arima_predictions.to_csv('prophet_results.csv')
