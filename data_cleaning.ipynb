# %%
#libraries import

import pandas as pd
import seaborn as sns

# %%
df = pd.read_excel('data2.xlsx')

# %%
df
# Out:
#      Unnamed: 0   Rok  Tydzień Roku  ES080E  ES1000E  ES100E  ES1200E  ES125E  \
# 0             0  2015            14       0        0       0        0       0
# 1             1  2015            15      20        6      20        0       0
# 2             2  2015            16       0        0      46        0       0
# 3             3  2015            17       0        0      34        0       0
# 4             4  2015            18       0        0     146        0       0
# ..          ...   ...           ...     ...      ...     ...      ...     ...
# 405         405  2023             1       0        0       0        0       0
# 406         406  2023             2      18        0      44        0       4
# 407         407  2023             3      36        0      24        0       0
# 408         408  2023             4      14        0      28        0       8
# 409         409  2023             5      16        0      28        0       0
#
# ...

# %%
df.describe()
# Out:
#        Unnamed: 0          Rok  Tydzień Roku      ES080E     ES1000E  \
# count  410.000000   410.000000    410.000000  410.000000  410.000000
# mean   204.500000  2018.660976     26.960976   26.004878    0.136585
# std    118.501055     2.281999     15.052262   37.712981    0.713734
# min      0.000000  2015.000000      1.000000    0.000000    0.000000
# 25%    102.250000  2017.000000     14.000000    2.000000    0.000000
# 50%    204.500000  2019.000000     27.000000   14.000000    0.000000
# 75%    306.750000  2021.000000     40.000000   34.000000    0.000000
# max    409.000000  2023.000000     53.000000  262.000000    6.000000
#
#            ES100E     ES1200E      ES125E      ES150E      ES200E  ...  \
# count  410.000000  410.000000  410.000000  410.000000  410.000000  ...
# mean    57.653659    0.053659    2.863415   47.278049   19.600000  ...
# std     69.692633    0.819714    8.947873   55.004474   23.610863  ...
# ...

# %%
df = df.fillna(0)

# %%
df
# Out:
#      Unnamed: 0   Rok  Tydzień Roku  ES080E  ES1000E  ES100E  ES1200E  ES125E  \
# 0             0  2015            14       0        0       0        0       0
# 1             1  2015            15      20        6      20        0       0
# 2             2  2015            16       0        0      46        0       0
# 3             3  2015            17       0        0      34        0       0
# 4             4  2015            18       0        0     146        0       0
# ..          ...   ...           ...     ...      ...     ...      ...     ...
# 405         405  2023             1       0        0       0        0       0
# 406         406  2023             2      18        0      44        0       4
# 407         407  2023             3      36        0      24        0       0
# 408         408  2023             4      14        0      28        0       8
# 409         409  2023             5      16        0      28        0       0
#
# ...

# %%
products = df.columns[2:1264]

# %%
products
# Out:
# Index(['Tydzień Roku', 'ES080E', 'ES1000E', 'ES100E', 'ES1200E', 'ES125E',
#        'ES150E', 'ES200E', 'ES200E/16', 'ES250E',
#        ...
#        'XS400E/16', 'XS450E', 'XS450E/16', 'XS500E', 'XS500E/16', 'XS600E',
#        'XS600E/16', 'XS700E', 'XS700E/16', 'XS800E'],
#       dtype='object', length=1262)

# %%
df[products] = df[products].apply(lambda x: x*2)

# %%
df
# Out:
#      Unnamed: 0   Rok  Tydzień Roku  ES080E  ES1000E  ES100E  ES1200E  ES125E  \
# 0             0  2015            14       0        0       0        0       0
# 1             1  2015            15      20        6      20        0       0
# 2             2  2015            16       0        0      46        0       0
# 3             3  2015            17       0        0      34        0       0
# 4             4  2015            18       0        0     146        0       0
# ..          ...   ...           ...     ...      ...     ...      ...     ...
# 405         405  2023             1       0        0       0        0       0
# 406         406  2023             2      18        0      44        0       4
# 407         407  2023             3      36        0      24        0       0
# 408         408  2023             4      14        0      28        0       8
# 409         409  2023             5      16        0      28        0       0
#
# ...

# %%
df[products] = df[products].astype(int)

# %%
df
# Out:
#       Rok  Tydzień Roku  ES080E  ES1000E  ES100E  ES1200E  ES125E  ES150E  \
# 0    2015            14       0        0       0        0       0       0
# 1    2015            15      20        6      20        0       0      60
# 2    2015            16       0        0      46        0       0       6
# 3    2015            17       0        0      34        0       0      90
# 4    2015            18       0        0     146        0       0      38
# ..    ...           ...     ...      ...     ...      ...     ...     ...
# 405  2023             1       0        0       0        0       0      10
# 406  2023             2      18        0      44        0       4      28
# 407  2023             3      36        0      24        0       0       4
# 408  2023             4      14        0      28        0       8      14
# 409  2023             5      16        0      28        0       0      54
#
#      ES200E  ES200E/16  ...  XS500E/16  XS600E  XS600E/16  XS700E  XS700E/16  \
# ...

# %%
df.to_excel('data2.xlsx')

# %%
df.to_csv('data_cleaned.csv')

# %%
df.drop('Unnamed: 0', axis = 'columns', inplace = True)

# %%
df
# Out:
#       Rok  Tydzień Roku  ES080E  ES1000E  ES100E  ES1200E  ES125E  ES150E  \
# 0    2015            14       0        0       0        0       0       0
# 1    2015            15      20        6      20        0       0      60
# 2    2015            16       0        0      46        0       0       6
# 3    2015            17       0        0      34        0       0      90
# 4    2015            18       0        0     146        0       0      38
# ..    ...           ...     ...      ...     ...      ...     ...     ...
# 405  2023             1       0        0       0        0       0      10
# 406  2023             2      18        0      44        0       4      28
# 407  2023             3      36        0      24        0       0       4
# 408  2023             4      14        0      28        0       8      14
# 409  2023             5      16        0      28        0       0      54
#
#      ES200E  ES200E/16  ...  XS500E/16  XS600E  XS600E/16  XS700E  XS700E/16  \
# ...
